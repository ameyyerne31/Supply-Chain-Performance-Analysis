# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
SC = pd.read_csv("supply_chain_data.csv")
SC.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
#check deatils of dataset
SC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
#get no of rows and columns
SC.shape
# Out:
# (100, 24)

# %%
#check null values
SC.isnull().sum()
# Out:
# Product type               0
# SKU                        0
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             0
# Shipping carriers          0
# Shipping costs             0
# Supplier name              0
# Location                   0
# Lead time                  0
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        0
# Inspection results         0
# Defect rates               0
# Transportation modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %%
SC.sample()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 51     haircare  SKU51  26.700761            61                      154
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 51        9866.465458                  Male           100           4
#
#     Order quantities  ...   Location Lead time  Production volumes  \
# 51                52  ...  Bangalore        18                 673
#
#    Manufacturing lead time Manufacturing costs  Inspection results  \
# 51                      28           14.190328             Pending
#
#     Defect rates  Transportation modes   Routes       Costs
# 51      1.772951                  Road  Route A  694.982318
#
# [1 rows x 24 columns]

# %%
SC['Shipping times'].value_counts()
# Out:
# Shipping times
# 8     16
# 7     14
# 9     11
# 4     10
# 6     10
# 3     10
# 1     10
# 5      8
# 10     6
# 2      5
# Name: count, dtype: int64

# %%
SC['Shipping carriers'].value_counts()
# Out:
# Shipping carriers
# Carrier B    43
# Carrier C    29
# Carrier A    28
# Name: count, dtype: int64

# %%
#check for duplicate values
SC.duplicated().sum()
# Out:
# 0

# %%
# Separate numerical and categorical columns
numerical_cols = SC.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = SC.select_dtypes(include=['object', 'category']).columns.tolist()

print("Numerical Columns:", numerical_cols)
print("Categorical Columns:", categorical_cols)
# Out:
# Numerical Columns: ['Price', 'Availability', 'Number of products sold', 'Revenue generated', 'Stock levels', 'Lead times', 'Order quantities', 'Shipping times', 'Shipping costs', 'Lead time', 'Production volumes', 'Manufacturing lead time', 'Manufacturing costs', 'Defect rates', 'Costs']
# Categorical Columns: ['Product type', 'SKU', 'Customer demographics', 'Shipping carriers', 'Supplier name', 'Location', 'Inspection results', 'Transportation modes', 'Routes']

# %%
#create count plot for categorical columns
for col in categorical_cols:
    plt.figure(figsize=(10, 6))  # Adjust figure size
    sns.countplot(x=col, data=SC, palette='viridis')
    plt.title(f'Countplot of {col}')
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.show()
# Out:
# C:\Users\yerne\AppData\Local\Temp\ipykernel_30264\4245820667.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=SC, palette='viridis')
# C:\Users\yerne\AppData\Local\Temp\ipykernel_30264\4245820667.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=SC, palette='viridis')
# C:\Users\yerne\AppData\Local\Temp\ipykernel_30264\4245820667.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=SC, palette='viridis')
# ...

# %%
# Generate a list of colors from the 'coolwarm' palette
palette = sns.color_palette("viridis", n_colors=len(numerical_cols))

# Plotting histograms for each numerical column
for column, color in zip(numerical_cols, palette):
    plt.figure()  # Creates a new figure
    SC[column].hist(bins=10, color=color)  # Set color for each histogram
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    
    # Calculate mean, median, and mode
    mean_value = SC[column].mean()
    median_value = SC[column].median()
    mode_value = SC[column].mode().values[0]  # Handling multimodal data
    
    # Add vertical lines for mean, median, and mode
    plt.axvline(mean_value, color='r', linestyle='dashed', linewidth=1, label='Mean')
    plt.axvline(median_value, color='g', linestyle='dashed', linewidth=1, label='Median')
    plt.axvline(mode_value, color='b', linestyle='dashed', linewidth=1, label='Mode')
    
    # You can also add text annotations instead of lines
    # plt.text(mean_value, 100, f'Mean: {mean_value}', rotation=90)
    # plt.text(median_value, 100, f'Median: {median_value}', rotation=90)
    # plt.text(mode_value, 100, f'Mode: {mode_value}', rotation=90)
    
    plt.legend()
    plt.show()

# %%
# Using describe on numerical columns
description = SC[numerical_cols].describe()

print(description)
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462461     48.400000               460.990000        5776.048187
# std     31.168193     30.743317               303.780074        2732.841744
# min      1.699976      1.000000                 8.000000        1061.618523
# 25%     19.597823     22.750000               184.250000        2812.847151
# 50%     51.239831     43.500000               392.500000        6006.352023
# 75%     77.198228     75.000000               704.250000        8253.976921
# max     99.171329    100.000000               996.000000        9866.465458
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# ...

# %%
# Compute the correlation matrix
corr = SC[numerical_cols].corr()

# Generate a heatmap
plt.figure(figsize=(10, 8))  # Size of the figure
sns.heatmap(corr, annot=True, cmap='viridis', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %%
# Extract the correlations between independent variables and the dependent variable
correlation_with_dependent = corr['Revenue generated']

# Sort the correlations in descending order
sorted_correlations = correlation_with_dependent.abs().sort_values(ascending=False)

# Display the attributes in descending order of correlation with the dependent variable
for attribute in sorted_correlations.index:
    correlation_percent = sorted_correlations[attribute] * 100
    print(f'{attribute} and dependent variable = {correlation_percent:.2f}%')
# Out:
# Revenue generated and dependent variable = 100.00%
# Manufacturing costs and dependent variable = 21.40%
# Stock levels and dependent variable = 15.85%
# Defect rates and dependent variable = 12.53%
# Shipping times and dependent variable = 10.92%
# Availability and dependent variable = 7.52%
# Shipping costs and dependent variable = 7.29%
# Lead times and dependent variable = 5.73%
# Price and dependent variable = 3.84%
# Production volumes and dependent variable = 3.74%
# Order quantities and dependent variable = 2.94%
# Costs and dependent variable = 2.73%
# Lead time and dependent variable = 1.42%
# Manufacturing lead time and dependent variable = 1.41%
# Number of products sold and dependent variable = 0.16%

# %%
# Lead time analysis
import plotly.express as px
fig_lead_times = px.box(
    SC,
    y=['Lead times', 'Manufacturing lead time', 'Shipping times'],
    title='Distribution of Lead Times',
    labels={'value': 'Time (Days)', 'variable': 'Lead Time Type'},
    color_discrete_sequence=px.colors.sequential.Viridis
    
)

# Show the plot
fig_lead_times.show()

# %%
#Number of products sold per Product type
import plotly.express as px
# Group by 'Product type' and sum the 'Number of products sold'
grouped_df = SC.groupby('Product type')['Number of products sold'].sum().reset_index()

# Create the Plotly bar chart
fig_productsold_bytype = px.bar(grouped_df, x='Product type', y='Number of products sold',
             title='Number of Products Sold per Product Type',
             labels={'Product type': 'Product Type', 'Number of products sold': 'Number of Products Sold'},
             color_discrete_sequence=px.colors.sequential.Viridis)                  

# Show the plot
fig_productsold_bytype.show()

# %%
import plotly.express as px

# Create the Plotly figure with a valid color sequence
fig_demographics = px.histogram(SC, x='Product type', color='Customer demographics', barmode='group',
                                title='Product Type vs Customer Demographics',
                                labels={'Product type': 'Product Type', 'count': 'Count', 'Customer demographics': 'Demographics'},
                                color_discrete_sequence=px.colors.sequential.Viridis)
# Show the figure
fig_demographics.show()

# %%
#product type vs location
import plotly.express as px


fig_location = px.histogram(SC, x='Product type', color='Location', title='Product Type vs Location', barmode='group',
             labels={'Product type': 'Product Type', 'Location': 'Location', 'count': 'Count'},
             color_discrete_sequence=px.colors.sequential.Viridis)
fig_location.show()

# %%
import plotly.express as px

#shipping carrier vs supplier name
fig_shippingcarrier = px.bar(SC, x='Shipping carriers', color='Supplier name', title='Shipping carriers vs Supplier name',
             labels={'Shipping carriers': 'Shipping Carriers', 'Supplier name': 'Supplier Name', 'count': 'Count'},
             category_orders={'Shipping carriers': sorted(SC['Shipping carriers'].unique())},
             color_discrete_sequence=px.colors.sequential.Viridis)
fig_shippingcarrier.show()

# %%
#Product type vs Supplier
# Assuming SC is your DataFrame
fig_supplier = px.bar(SC, x='Product type', color='Supplier name', title='Product Type vs Supplier Name',
             labels={'Product type': 'Product Type', 'Supplier name': 'Supplier Name', 'count': 'Count'},
             category_orders={'Product type': sorted(SC['Product type'].unique())},
             color_discrete_sequence=px.colors.sequential.Viridis)

fig_supplier.show()

# %%
import plotly.express as px

# Shipping carriers vs location
fig_supplier_prodType = px.histogram(SC, x='Shipping carriers', color='Location', title='Shipping Carriers vs Location',
             labels={'Shipping carriers': 'Shipping Carriers', 'Location': 'Location', 'count': 'Count'},
             category_orders={'Shipping carriers': sorted(SC['Shipping carriers'].unique())},
             color_discrete_sequence=px.colors.sequential.Viridis)

fig_supplier_prodType.show()

# %%
#Cost analysis Manufacturing costs and shipping costs
# Aggregate costs by product type
grouped_df = SC.groupby('Product type').sum().reset_index()

# Melt the DataFrame for Plotly
melted_df = grouped_df.melt(id_vars='Product type', value_vars=['Manufacturing costs', 'Shipping costs'],
                            var_name='Cost Type', value_name='Cost')

# Create the Plotly stacked bar chart
fig_manufacturing_shippingcosts = px.bar(melted_df, x='Product type', y='Cost', color='Cost Type', color_discrete_sequence=px.colors.sequential.Viridis,barmode='stack',
             title='Breakdown of Costs by Product Type',
             labels={'Product type': 'Product Type', 'Cost': 'Cost', 'Cost Type': 'Cost Type'})

# Show the plot
fig_manufacturing_shippingcosts.show()

# %%
import plotly.express as px

# Assuming SC is a pandas DataFrame already defined
fig_productssold_bytype_loc = px.scatter(
    SC, 
    x='Availability', 
    y='Number of products sold', 
    color='Product type', 
    color_discrete_sequence=px.colors.sequential.Viridis, 
    size='Number of products sold',
    title='Availability vs Number of Products Sold by Product Type',
    labels={
        'Availability': 'Availability', 
        'Number of products sold': 'Number of Products Sold'
    },
    hover_data=['Product type']
)

# Show the plot
fig_productssold_bytype_loc.show()

# %%
import plotly.express as px

# Supplier name vs location
fig_supplier_location = px.bar(SC, x='Supplier name', color='Location', title='Supplier Name vs Location',
             labels={'Supplier name': 'Supplier Name', 'Location': 'Location', 'count': 'Count'},
             category_orders={'Supplier name': sorted(SC['Supplier name'].unique())},
             color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance
fig_supplier_location.update_layout(xaxis_title='Supplier Name', yaxis_title='Count', legend_title='Location')

fig_supplier_location.show()

# %%
import plotly.express as px

# Product type vs inspection results
fig_productype_inspection = px.bar(SC, x='Product type', color='Inspection results', title='Product Type vs Inspection Results',
             labels={'Product type': 'Product Type', 'Inspection results': 'Inspection Results', 'count': 'Count'},
             category_orders={'Product type': sorted(SC['Product type'].unique())},
             color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance
fig_productype_inspection.update_layout(xaxis_title='Product Type', yaxis_title='Count', legend_title='Inspection Results')

fig_productype_inspection.show()

# %%
import plotly.express as px

# Product Type vs transportation mode
fig_productType_transportation = px.bar(SC, x='Product type', color='Transportation modes', title='Product Type vs Transportation Modes',
             labels={'Product type': 'Product Type', 'Transportation modes': 'Transportation Modes', 'count': 'Count'},
             category_orders={'Product type': sorted(SC['Product type'].unique())},
             color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance
fig_productType_transportation.update_layout(xaxis_title='Product Type', yaxis_title='Count', legend_title='Transportation Modes')

fig_productType_transportation.show()

# %%
import plotly.express as px

#Shipping carriers vs Transportation mode
fig_shipping_transportation = px.bar(SC, x='Shipping carriers', color='Transportation modes', title='Shipping Carriers vs Transportation Modes',
             labels={'Shipping carriers': 'Shipping Carriers', 'Transportation modes': 'Transportation Modes', 'count': 'Count'},
             category_orders={'Shipping carriers': sorted(SC['Shipping carriers'].unique())},
             color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance
fig_shipping_transportation.update_layout(xaxis_title='Shipping Carriers', yaxis_title='Count', legend_title='Transportation Modes')

fig_shipping_transportation.show()

# %%
#Shipping carriers vs Routes

fig_shipping_routes = px.histogram(SC, x='Shipping carriers', color='Routes', title='Shipping carriers vs Routes', barmode='group',
             labels={'Shipping carriers': 'Shipping Carriers', 'Routes': 'Routes', 'count': 'Count'},
             category_orders={'Shipping carriers': sorted(SC['Shipping carriers'].unique())},
             color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance
fig_shipping_routes.update_layout(xaxis_title='Shipping Carriers', yaxis_title='Count', legend_title='Routes')

fig_shipping_routes.show()

# %%
#Transportation modes vs Routes

fig_transportationmode_routes = px.histogram(SC, x='Transportation modes', color='Routes', title='Transportation modes vs Routes', barmode='group',
             labels={'Transportation modes': 'Transportation modes', 'Routes': 'Routes', 'count': 'Count'},
             category_orders={'Transportation modes': sorted(SC['Transportation modes'].unique())},
             color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance
fig_transportationmode_routes.update_layout(xaxis_title='Transportation modes', yaxis_title='Count', legend_title='Routes')

fig_transportationmode_routes.show()

# %%
# Shipping carriers vs Shippping costs
fig_shippingcarrier_costs = px.bar(SC, x='Shipping carriers', y='Shipping costs', title='Shipping Carriers vs Shipping Costs',
             labels={'Shipping carriers': 'Shipping Carriers', 'Shipping costs': 'Shipping Costs'},
             color='Shipping carriers', color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance
fig_shippingcarrier_costs.update_layout(xaxis_title='Shipping Carriers', yaxis_title='Shipping Costs', legend_title='Shipping Carriers')

fig_shippingcarrier_costs.show()

# %%
# Shipping carriers vs Shippping time
fig_shippingcarrier_times = px.bar(SC, x='Shipping carriers', y='Shipping times', title='Shipping Carriers vs Shipping times',
             labels={'Shipping carriers': 'Shipping Carriers', 'Shipping times': 'Shipping times'},
             color='Shipping carriers', color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance
fig_shippingcarrier_times.update_layout(xaxis_title='Shipping Carriers', yaxis_title='Shipping times', legend_title='Shipping times')

fig_shippingcarrier_times.show()

# %%
# Shipping carriers vs Inspection results
fig_carrier_inspection = px.histogram(SC, x='Shipping carriers', color='Inspection results', title='Shipping Carriers vs Inspection Results',barmode='group',
             labels={'Shipping carriers': 'Shipping Carriers', 'Inspection results': 'Inspection Results', 'count': 'Count'},
             category_orders={'Shipping carriers': sorted(SC['Shipping carriers'].unique())},
             color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance
fig_carrier_inspection.update_layout(xaxis_title='Shipping Carriers', yaxis_title='Count', legend_title='Inspection Results')

fig_carrier_inspection.show()

# %%
# Product types vs Manufacturing costs
fig_product_manufacturingcost = px.bar(SC, x='Product type', y='Manufacturing costs', title='Product Type vs Manufacturing Costs',
             labels={'Product type': 'Product Type', 'Manufacturing costs': 'Manufacturing Costs'},
             color='Product type', color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance
fig_product_manufacturingcost.update_layout(xaxis_title='Product Type', yaxis_title='Manufacturing Costs', legend_title='Product Type')

fig_product_manufacturingcost.show()

# %%
# Product types vs Manufacturing lead time
fig_product_manufacturingleadtime = px.bar(SC, x='Product type', y='Manufacturing lead time', title='Product Type vs Manufacturing lead time',
             labels={'Product type': 'Product Type', 'Manufacturing lead time': 'Manufacturing lead time'},
             color='Product type', color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance
fig_product_manufacturingleadtime.update_layout(xaxis_title='Product Type', yaxis_title='Manufacturing lead time', legend_title='Product Type')

fig_product_manufacturingleadtime.show()

# %%
# Calculate average revenue per product type
average_revenue = SC.groupby('Product type')['Revenue generated'].mean().reset_index()

# Create a Plotly bar plot
fig_average_revenue = px.bar(average_revenue, x='Product type', y='Revenue generated', title='Average Revenue Generated by Product Type',
             labels={'Product type': 'Product Type', 'Revenue generated': 'Average Revenue Generated'},
             color='Product type', color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance and to set y-axis limit
fig_average_revenue.update_layout(xaxis_title='Product Type', yaxis_title='Average Revenue Generated', 
                  legend_title='Product Type', yaxis=dict(range=[0, average_revenue['Revenue generated'].max() + 50]))

fig_average_revenue.show()

# %%
# Calculate average shipping costs per carrier
average_costs = SC.groupby('Shipping carriers')['Shipping costs'].mean().reset_index()

# Create a Plotly bar plot
fig_avgcostpercarrier = px.bar(average_costs, x='Shipping carriers', y='Shipping costs', title='Average Shipping Costs by Carrier',
             labels={'Shipping carriers': 'Shipping Carrier', 'Shipping costs': 'Average Shipping Costs'},
             color='Shipping carriers', color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance and to set y-axis limit
fig_avgcostpercarrier.update_layout(xaxis_title='Shipping Carrier', yaxis_title='Average Shipping Costs', 
                  legend_title='Shipping Carrier', yaxis=dict(range=[0, average_costs['Shipping costs'].max() + 5]))

# Add text annotations on the bars
fig_avgcostpercarrier.update_traces(texttemplate='%{y:.2f}', textposition='outside')

fig_avgcostpercarrier.show()

# %%
SC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
# Product types vs shipping carriers vs defect rates
fig_productshippingdefectrate = px.bar(SC, x='Shipping carriers', y='Defect rates', color='Product type',color_discrete_sequence=px.colors.sequential.Viridis,
             title='Defect Rates vs Shipping Carriers vs Product Types',
             labels={'Shipping carriers': 'Shipping Carriers', 'Defect rates': 'Defect Rates',
                     'Product type': 'Product Type'},
             barmode='group',
             )

fig_productshippingdefectrate.update_layout(xaxis_title='Shipping Carriers', yaxis_title='Defect Rates', legend_title='Product Type')

fig_productshippingdefectrate.show()

# %%
#Number of products sold by Product type and location

fig_productype_location = px.bar(SC, x='Product type', y='Number of products sold', color='Location', title='Number of Products Sold by Product Type and Location',
             labels={'Product type': 'Product Type', 'Number of products sold': 'Number of Products Sold', 'Location': 'Location'},
             barmode='group', color_discrete_sequence=px.colors.sequential.Viridis)

# Update layout for better appearance and to rotate x-axis labels
fig_productype_location.update_layout(xaxis_title='Product Type', yaxis_title='Number of Products Sold', legend_title='Location')
fig_productype_location.update_xaxes(tickangle=45)

fig_productype_location.show()

# %%
# Define the pairs of numerical variables for joint plots
jointplot_pairs = [('Stock levels', 'Lead times'),
                   ('Order quantities', 'Production volumes'),
                   ('Shipping times', 'Shipping costs'),
                   ('Manufacturing lead time', 'Manufacturing costs'),
                   ('Number of products sold', 'Revenue generated'),
                   ('Availability', 'Defect rates')]

# Create joint plots for each pair of numerical variables
for pair in jointplot_pairs:
    sns.jointplot(data=SC, x=pair[0], y=pair[1], kind='scatter', marginal_ticks=True)
    plt.suptitle(f'{pair[0]} vs {pair[1]}', y=1.02)
    plt.show()

# %%
import plotly.graph_objects as go
import pandas as pd


# Create a list of unique product types
product_types = SC['Product type'].unique()

# Create a figure
fig = go.Figure()

# Iterate through each product type
for product_type in product_types:
    # Filter data for the current product type
    filtered_data = SC[SC['Product type'] == product_type]
    
    # Add trace for availability
    fig.add_trace(go.Scatter(x=filtered_data.index, y=filtered_data['Availability'],
                             mode='lines+markers', name=f'Availability - {product_type}'))
    
    # Add trace for stock levels
    fig.add_trace(go.Scatter(x=filtered_data.index, y=filtered_data['Stock levels'],
                             mode='lines+markers', name=f'Stock Levels - {product_type}'))

# Update layout
fig.update_layout(title='Availability and Stock Levels Over Time by Product Type',
                  xaxis_title='Time',
                  yaxis_title='Percentage / Units',
                  legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01))

# Show interactive plot
fig.show()
